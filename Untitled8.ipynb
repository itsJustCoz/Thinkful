# %%
import pandas as pd
import numpy as np

df = pd.read_csv('plane_crashes_data (1).csv', index_col=0)


df
# Out:
#       hour  year                                           location  \
# month
# 1       12  1950                                Near Vacas, Bolivia
# 3       20  1950                             Minneapolis, Minnesota
# 3       14  1950                    Llandow Airport, Cardiff, Wales
# 4       23  1950                                 Near Atsugi, Japan
# 5       20  1950                      Lagens Air Force Base, Azores
# 5       10  1950                       Myrtle Beach, South Carolina
# 5       17  1950                              Teterboro, New Jersey
# 6       22  1950                           AtlantiOcean off Florida
# 6       19  1950                             Near Fonseca, Colombia
# 6       21  1950                                        Off Bahrain
# 6       21  1950                                        Off Bahrain
# 6       23  1950   Lake Michigan, 18 NNW of Benton Harbor, Michigan
# 6       23  1950                                    York, Australia
# ...

# %%
import statistics

df_year = df[(df["year"] >= 1980) & (df["year"]<=2009)]
df_year
# Out:
#       hour  year                                           location  \
# month
# 1        1  1980                              Over the AtlantiOcean
# 1       14  1980                                   Shungnak, Alaska
# 1       19  1980         Elburz Mtns., near Laskarak, Markazi, Iran
# 1        6  1980                               Near Mandalay, Burma
# 2        8  1980                                Leeville, Louisiana
# 2        6  1980                                Manila, Philippines
# 3       11  1980                                Near Warsaw, Poland
# 3       15  1980                                Near Yenice, Turkey
# 3       19  1980                                     Houston, Texas
# 4       20  1980                              Florianopolis, Brazil
# 4       13  1980                           Tenerife, Canary Islands
# 4        6  1980                                Don Muang, Thailand
# 5       12  1980                              Off Sarasota, Florida
# ...

# %%
df_year['fatalities'].mean()
# Out:
# 24.932607215793055

# %%
df['fatalities'].max()
# Out:
# 583

# %%
df_zero= df[df['fatalities'] < 1]
1-(df_zero['fatalities'].count())/df['fatalities'].count()
# Out:
# 0.98191214470284238

# %%
df_fatal_aboard = df['fatalities']/df['aboard']
df_fatal_aboard

print(df_fatal_aboard.sum()/df['fatalities'].count())
# Out:
# 0.822828071512
